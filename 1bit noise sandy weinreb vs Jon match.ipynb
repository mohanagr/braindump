# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
rho = 10**np.linspace(-3,-0.1,101)
snr = (1-rho)/rho
rho2 = 2*np.arcsin(rho)/np.pi
N=100000
sigma_inf = np.sqrt((1+rho**2)/N)
sigma_2 = np.pi/2 * np.sqrt((1-rho**2)*(1-rho2**2)/N)
ratio = sigma_inf/sigma_2

# %% [markdown]
# sin(pi/2 rho_2) = rho

# %%
sigma_2new = np.cos(np.pi/2 * rho2) * np.sqrt((1-rho2**2)/N) * np.pi/2

# %%
plt.plot(rho,sigma_2)
plt.plot(rho,sigma_2new)

# %%
1/(sigma_2*np.sqrt(N))
# Out:
# array([0.63662022, 0.63662028, 0.63662036, 0.63662044, 0.63662054,
#        0.63662064, 0.63662077, 0.63662091, 0.63662107, 0.63662126,
#        0.63662147, 0.63662172, 0.63662199, 0.63662231, 0.63662267,
#        0.63662309, 0.63662356, 0.6366241 , 0.63662472, 0.63662543,
#        0.63662624, 0.63662716, 0.63662822, 0.63662942, 0.6366308 ,
#        0.63663238, 0.63663418, 0.63663624, 0.63663859, 0.63664128,
#        0.63664436, 0.63664787, 0.63665188, 0.63665647, 0.63666171,
#        0.63666771, 0.63667456, 0.63668239, 0.63669133, 0.63670156,
#        0.63671325, 0.6367266 , 0.63674187, 0.63675932, 0.63677927,
#        0.63680206, 0.63682812, 0.6368579 , 0.63689194, 0.63693085,
#        0.63697533, 0.63702617, 0.63708429, 0.63715073, 0.63722668,
#        0.63731351, 0.63741278, 0.63752628, 0.63765606, 0.63780446,
#        0.63797417, 0.63816826, 0.63839026, 0.63864421, 0.63893475,
#        0.6392672 , 0.63964767, 0.64008318, 0.6405818 , 0.64115284,
# ...
