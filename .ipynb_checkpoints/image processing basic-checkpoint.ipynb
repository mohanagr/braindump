# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
dat=plt.imread('/home/mohan/Downloads/marion_penguins2.jpg')

# %%
dat.shape
# Out:
# (3826, 3825, 3)

# %%
fig,ax=plt.subplots(1,1)
fig.set_size_inches(10,8)
ax.imshow(dat[1330:1330+2048,1100:1100+2048,0],aspect='equal')
# plt.colorbar()

# %%
r=dat[1330:1330+2048,1100:1100+2048,0].copy()
b=dat[1330:1330+2048,1100:1100+2048,1].copy()
g=dat[1330:1330+2048,1100:1100+2048,2].copy()
print(im.shape)
# Out:
# (2048, 2048)

# %%
def get_filtered_channel(im,res):
    imfft=np.fft.fft2(im)
    N = im.shape[0]
    kres = 1/np.deg2rad(5)
    kmax = N*kres/2
    new_kmax=1/(2*res)
#     new_kmax=int(kmax/239)
    print(kres,kmax,new_kmax)
    kcutoff=int(new_kmax/kres)
    print(kcutoff)
    sigma=kcutoff
    vec=np.fft.fftfreq(N)*N
    # print(vec)
    X,Y=np.meshgrid(vec,vec)
#     print(X)
    kernel= 10*np.exp(-0.5*(X**2+Y**2)/sigma**2)
    newfft=imfft*kernel
    return np.fft.ifft2(newfft).real

# %%
7/(1*60/2048)
# Out:
# 238.93333333333334

# %%
newres=np.deg2rad(120/60)
newimg=np.zeros((2048,2048,3),dtype='float64')
newimg[:,:,0]=get_filtered_channel(r,newres)
newimg[:,:,1]=get_filtered_channel(b,newres)
newimg[:,:,2]=get_filtered_channel(g,newres)
# Out:
# 11.459155902616464 11734.17564427926 14.32394487827058
# 1
# 11.459155902616464 11734.17564427926 14.32394487827058
# 1
# 11.459155902616464 11734.17564427926 14.32394487827058
# 1

# %%
# Out:
# 34

# %%
plt.imshow(np.fft.fftshift(np.abs(imfft))/1000,aspect='auto',vmax=1)
plt.colorbar()

# %%
vec=np.fft.fftfreq(N)*N
# print(vec)
X,Y=np.meshgrid(vec,vec)

# %%
# a highpass filter
kernel=np.ones((N,N))
kernel[X**2+Y**2<=4]=0

# %%
sigma=kcutoff
kernel= 10*np.exp(-0.5*(X**2+Y**2)/sigma**2)
plt.imshow(np.fft.fftshift(kernel),aspect='equal')
plt.colorbar()

# %%
newimfft=imfft*kernel

# %%
fig=plt.gcf()
# fig.set_size_inches(10,8)
plt.imshow(newimg[:,:,0],aspect='equal',extent=[-5,5,-5,5],cmap='inferno')
