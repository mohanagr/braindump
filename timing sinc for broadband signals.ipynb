# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dk=4096
N=4096
n=np.arange(-100,100)
plt.plot(np.sinc(dk * n / N))

# %%
#we can reconstruct the original xcorr by rechannelizing really finely and then making sinc assumption for each narrow channel.

# %%
# = stepwise approximation
