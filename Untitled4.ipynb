# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.linspace(-10,10,100)
y=10*np.exp(-0.5*x**2)

plt.plot(x,y)

# %%
plt.plot(np.fft.irfft(np.fft.rfft(y[50:])))

# %%
plt.plot(np.fft.irfft(np.fft.rfft(y[50:])))
