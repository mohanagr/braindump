# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
N = 16
# n = np.arange(0,N)
k=4
# x = np.sign(np.sin(2*np.pi*n*k/N))
x = np.ones(N)
x[N//2:] = -1
x = np.tile(x,k)
plt.plot(x)

# %%
f=np.fft.fft(x)

# %%
plt.plot(np.abs(f))
plt.xlim(0,18)
# Out:
# (0.0, 18.0)

# %%
f[0:10]
# Out:
# array([0.00000000e+00+0.00000000e+00j, 2.22044605e-16+2.22044605e-16j,
#        0.00000000e+00+0.00000000e+00j, 6.00000000e+00-3.01640370e+01j,
#        0.00000000e+00+0.00000000e+00j, 0.00000000e+00+4.44089210e-16j,
#        0.00000000e+00+0.00000000e+00j, 0.00000000e+00+0.00000000e+00j,
#        0.00000000e+00+0.00000000e+00j, 6.00000000e+00-8.97963458e+00j])

# %%
def analytic(N):
    f = np.zeros(N,dtype='complex128')
    idx = np.arange(1,N,2)
    f[idx] = 2 *(np.exp(-1J*idx*np.pi)-1)/(np.exp(-2J*idx*np.pi/N) - 1)
    return f

# %%
np.abs(f-)
# Out:
# array([1., 3., 1., ..., 3., 1., 3.])

# %%
#

# %%
np.arange(1,N,2)
# Out:
# array([ 1,  3,  5,  7,  9, 11, 13, 15])
