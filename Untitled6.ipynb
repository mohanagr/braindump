# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.special import gamma, expi

# %%
n=100

# %%
ps=np.zeros(n+1)
freq=np.arange(n+1)
ps[1:]=1/freq[1:]

# %%
acf=np.fft.irfft(ps)

# %%
plt.plot(acf)

# %%
def get_C1(beta,k):
    return gamma(2-beta)*np.sin(np.pi/2*beta)/(np.pi*k)**(1-beta) + (-1)**k * beta*(beta-1)/(k*np.pi)**2

# %%
def get_C2(a,b,t):
    return expi(-t/a)- expi(-t/b)

# %%
taus=

# %%
C1=get_C1(0.6,taus)

# %%
plt.loglog(get_C1(0.6,taus))
plt.loglog(get_C1(0.2,taus))
plt.xlim(1,10)
# Out:
# (1, 10)

# %%
a=1
b=100
plt.plot(get_C2(a,b,np.arange(1,10000)))

# %%
C2=np.hstack([np.log(b/a),get_C2(a,b,taus)])
print(C2.shape)
plt.loglog(np.abs(np.fft.rfft(C2)))
# Out:
# (200,)

# %%
np.log(b/a)
# Out:
# 16.11809565095832

# %%
plt.plot(np.arctan(np.linspace(-10*np.pi/2,10*np.pi/2,101)))
