# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nside=1024
mymap=np.random.randn(nside*nside)
mymap=mymap.reshape(nside,nside)

# %%
mapft=np.fft.rfft2(mymap)

# %%
plt.imshow(np.abs(mapft[:512]),aspect='equal')

# %%
# Out:
# 10.0
